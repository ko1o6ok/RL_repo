# %% [markdown]
# # Deep Crossentropy method
#
# In this section we'll extend your CEM implementation with neural networks! You will train a multi-layer neural network to solve simple continuous state space games. __Please make sure you're done with tabular crossentropy method from the previous notebook.__
#
# ![img](https://watanimg.elwatannews.com/old_news_images/large/249765_Large_20140709045740_11.jpg)

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %%
# Install gymnasium if you didn't
# !pip install "gymnasium[toy_text,classic_control]"

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# if you see "<classname> has no attribute .env", remove .env or update gym
env = gym.make("CartPole-v0", render_mode="rgb_array").env

env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape[0]

plt.imshow(env.render())
print("state vector dim =", state_dim)
print("n_actions =", n_actions)

env.close()
# Out:
# C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# state vector dim = 4
# n_actions = 2

# %% [markdown]
# # Neural Network Policy
#
# For this assignment we'll utilize the simplified neural network implementation from __[Scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)__. Here's what you'll need:
#
# * `agent.partial_fit(states, actions)` - make a single training pass over the data. Maximize the probability of :actions: from :states:
# * `agent.predict_proba(states)` - predict probabilities of all actions, a matrix of shape __[len(states), n_actions]__

# %%
from sklearn.neural_network import MLPClassifier

agent = MLPClassifier(
    hidden_layer_sizes=(20, 20),
    activation="tanh",
)

# initialize agent to the dimension of state space and number of actions
agent.partial_fit([env.reset()[0]] * n_actions, list(range(n_actions)), classes=list(range(n_actions)))
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(20, 20))

# %%
def generate_session(env, agent, t_max=1000):
    """
    Play a single game using agent neural network.
    Terminate when game finishes or after :t_max: steps
    """
    states, actions = [], []
    total_reward = 0

    s, _ = env.reset()

    for t in range(t_max):

        # use agent to predict a vector of action probabilities for state :s:
        #probs = <YOUR CODE>
        expanded_s = np.expand_dims(s, axis=0)
        probs = agent.predict_proba(expanded_s)
        probs = probs.reshape((n_actions,))

        assert probs.shape == (env.action_space.n,), "make sure probabilities are a vector (hint: np.reshape)"

        # use the probabilities you predicted to pick an action
        # sample proportionally to the probabilities, don't just take the most likely action
        # a = <YOUR CODE>
        a = np.random.choice(range(n_actions), p = probs)
        # ^-- hint: try np.random.choice

        new_s, r, terminated, truncated, _ = env.step(a)

        # record sessions like you did before
        states.append(s)
        actions.append(a)
        total_reward += r

        s = new_s
        if terminated or truncated:
            break
    return states, actions, total_reward

# %%
dummy_states, dummy_actions, dummy_reward = generate_session(env, agent, t_max=5)
print("states:", np.stack(dummy_states))
print("actions:", dummy_actions)
print("reward:", dummy_reward)
# Out:
# states: [[ 0.04432914  0.01791477 -0.01389695  0.00163332]
#  [ 0.04468743  0.21323323 -0.01386429 -0.29540166]
#  [ 0.0489521   0.40855008 -0.01977232 -0.59242475]
#  [ 0.0571231   0.60394317 -0.03162081 -0.89126974]
#  [ 0.06920196  0.7994795  -0.04944621 -1.1937226 ]]
# actions: [np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
# reward: 5.0

# %% [markdown]
# ### CEM steps
# Deep CEM uses exactly the same strategy as the regular CEM, so you can copy your function code from previous notebook.
#
# The only difference is that now each observation is not a number but a `float32` vector.

# %%
def select_elites(states_batch, actions_batch, rewards_batch, percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i]

    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions

    Please return elite states and actions in their original order
    [i.e. sorted by session number and timestep within session]

    If you are confused, see examples below. Please don't assume that states are integers
    (they will become different later).
    """

    #<YOUR CODE: copy-paste your implementation from the previous notebook>

    reward_threshold = np.percentile(rewards_batch, percentile)

    #elite_states = <YOUR CODE>
    elite_states = []
    for i in range(len(states_batch)):
        if rewards_batch[i] > reward_threshold:
            elite_states.extend(states_batch[i])
    #elite_actions = <YOUR CODE>
    elite_actions = []
    for i in range(len(states_batch)):
        if rewards_batch[i] > reward_threshold:
            elite_actions.extend(actions_batch[i])

    return elite_states, elite_actions

# %% [markdown]
# # Training loop
# Generate sessions, select N best and fit to those.

# %%
from IPython.display import clear_output


def show_progress(rewards_batch, log, percentile, reward_range=[-990, +10]):
    """
    A convenience function that displays training progress.
    No cool math here, just charts.
    """

    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch, percentile)
    log.append([mean_reward, threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f" % (mean_reward, threshold))
    plt.figure(figsize=[8, 4])
    plt.subplot(1, 2, 1)
    plt.plot(list(zip(*log))[0], label="Mean rewards")
    plt.plot(list(zip(*log))[1], label="Reward thresholds")
    plt.legend()
    plt.grid()

    plt.subplot(1, 2, 2)
    plt.hist(rewards_batch, range=reward_range)
    plt.vlines(
        [np.percentile(rewards_batch, percentile)],
        [0],
        [100],
        label="percentile",
        color="red",
    )
    plt.legend()
    plt.grid()

    plt.show()

# %%
n_sessions = 100
percentile = 70
log = []

for i in range(100):
    # generate new sessions
    # sessions = [ <YOUR CODE: generate a list of n_sessions new sessions> ]
    sessions = [ generate_session(env, agent) for _ in range(n_sessions)]
    # states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))
    states_batch, actions_batch, rewards_batch = zip(*sessions)
    # elite_states, elite_actions = <YOUR CODE: select elite actions just like before>
    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)
    #<YOUR CODE: partial_fit agent to predict elite_actions(y) from elite_states(X)>

    agent.partial_fit(elite_states, elite_actions)

    show_progress(
        rewards_batch, log, percentile, reward_range=[0, np.max(rewards_batch)]
    )

    if np.mean(rewards_batch) > 190:
        print("You Win! You may stop training now via KeyboardInterrupt.")
# Out:
# mean reward = 223.920, threshold=257.900
# You Win! You may stop training now via KeyboardInterrupt.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       3 log = []
#       5 for i in range(100):
#       6     # generate new sessions
#       7     # sessions = [ <YOUR CODE: generate a list of n_sessions new sessions> ]
# ----> 8     sessions = [ generate_session(env, agent) for _ in range(n_sessions)]
#       9     # states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))
#      10     states_batch, actions_batch, rewards_batch = zip(*sessions)
#
# Cell In[17], line 24, in generate_session(env, agent, t_max)
#      19 assert probs.shape == (env.action_space.n,), "make sure probabilities are a vector (hint: np.reshape)"
#      21 # use the probabilities you predicted to pick an action
# ...

# %% [markdown]
# # Results

# %%
# Record sessions

from gymnasium.wrappers import RecordVideo

with RecordVideo(
    env=gym.make("CartPole-v0", render_mode="rgb_array"),
    video_folder="./videos",
    episode_trigger=lambda episode_number: True,
) as env_monitor:
    sessions = [generate_session(env_monitor, agent) for _ in range(100)]
# Out:
# C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at D:\Мага_1_год_весна\RL\notebooks\week_1\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
# Show video. This may not work in some setups. If it doesn't
# work for you, you can download the videos and view them locally.

from pathlib import Path
from base64 import b64encode
from IPython.display import HTML

video_paths = sorted([s for s in Path("videos").iterdir() if s.suffix == ".mp4"])
video_path = video_paths[-1]  # You can also try other indices

if "google.colab" in sys.modules:
    # https://stackoverflow.com/a/57378660/1214547
    with video_path.open("rb") as fp:
        mp4 = fp.read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
else:
    data_url = str(video_path)

HTML(
    """
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(
        data_url
    )
)
# Out:
# <video width="640" height="480" controls>
#   <source src="videos\rl-video-episode-99.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Homework part I
#
# ### Tabular crossentropy method
#
# You may have noticed that the taxi problem quickly converges from -100 to a near-optimal score and then descends back into -50/-100. This is in part because the environment has some innate randomness. Namely, the starting points of passenger/driver change from episode to episode.
#
# ### Tasks
# - __1.1__ (2 pts) Find out how the algorithm performance changes if you use a different `percentile` and/or `n_sessions`. Provide here some figures so we can see how the hyperparameters influence the performance.
# - __1.2__ (1 pts) Tune the algorithm to end up with positive average score.
#
# It's okay to modify the existing code.

# %% [markdown]
# ```<Describe what you did here>```
#
# **Что я сделал:**
# - 1.1. Нарисовал графики для временной эволюции Mean rewards для нескольких значений percentile при зафиксированном n_sessions. Также нарисовал аналогичные графики для нескольких значений n_sessions при фиксированном percentile.
#
# *Фиксировано количество сессий:*
# Как видно, с уменьшением перцентиля увеличивается средняя награда в конце прохода. Также, что ожидаемо, чем больший перцентиль мы берём, тем менее стабильный алгоритм мы получаем

# %%
from IPython.display import Image

# %%
display(Image(filename='mean_reward_on_perc.png'))

# %% [markdown]
# *Фиксирован перцентиль:*
# Как видно, с увеличением количества сессий алгоритм предсказуемо работает более устойчиво, а также находит более хорошие стратегии, что выражается в увеличении средней награды в конце прохода.

# %%
display(Image(filename='mean_reward_on_n_sess.png'))

# %% [markdown]
# - 1.2 Я использовал совет "For each starting state, you can sample an action randomly, and then evaluate this action by running several games starting from it and averaging the total reward. Choosing elite sessions with this kind of sampling (where each session's reward is counted as the average of the rewards of all sessions with the same starting state and action) should improve the performance of your policy.". Реализацию см. в файле crossentropy_method.ipynb

# %% [markdown]
# # Homework part II
#
# ### Deep crossentropy method
#
# By this moment, you should have got enough score on [CartPole-v0](https://gymnasium.farama.org/environments/classic_control/cart_pole/) to consider it solved (see the link). It's time to try something harder.
#
# * if you have any trouble with CartPole-v0 and feel stuck, feel free to ask us or your peers for help.
#
# ### Tasks
#
# * __2.1__ (3 pts) Pick one of environments: `MountainCar-v0` or `LunarLander-v2`.
#   * For MountainCar, get average reward of __at least -150__
#   * For LunarLander, get average reward of __at least +50__
#
# See the tips section below, it's kinda important.
# __Note:__ If your agent is below the target score, you'll still get some of the points depending on the result, so don't be afraid to submit it.
#
#
# * __2.2__ (up to 6 pts) Devise a way to speed up training against the default version
#   * Obvious improvement: use [`joblib`](https://joblib.readthedocs.io/en/latest/). However, note that you will probably need to spawn a new environment in each of the workers instead of passing it via pickling. (2 pts)
#   * Try re-using samples from 3-5 last iterations when computing threshold and training. (2 pts)
#   * Obtain __-100__ at `MountainCar-v0` or __+200__ at `LunarLander-v2` (2 pts). Feel free to experiment with hyperparameters, architectures, schedules etc.
#
# __Please list what you did in Anytask submission form__. This reduces probability that somebody misses something.
#
#
# ### Tips
# * Gymnasium pages: [MountainCar](https://gymnasium.farama.org/environments/classic_control/mountain_car/), [LunarLander](https://gymnasium.farama.org/environments/box2d/lunar_lander/)
# * Sessions for MountainCar may last for 10k+ ticks. Make sure ```t_max``` param is at least 10k.
#  * Also it may be a good idea to cut rewards via ">" and not ">=". If 90% of your sessions get reward of -10k and 10% are better, than if you use percentile 20% as threshold, R >= threshold __fails to cut off bad sessions__ while R > threshold works alright.
# * _issue with gym_: Some versions of gym limit game time by 200 ticks. This will prevent cem training in most cases. Make sure your agent is able to play for the specified __t_max__, and if it isn't, try `env = gym.make("MountainCar-v0").env` or otherwise get rid of TimeLimit wrapper.
# * If you use old _swig_ lib for LunarLander-v2, you may get an error. See this [issue](https://github.com/openai/gym/issues/100) for solution.
# * If it doesn't train, it's a good idea to plot reward distribution and record sessions: they may give you some clue. If they don't, call course staff :)
# * 20-neuron network is probably not enough, feel free to experiment.
#
# You may find the following snippet useful:

# %%
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym

def visualize_mountain_car(env, agent):
    # Get the unwrapped environment to access the attributes
    unwrapped_env = env.unwrapped
    
    # Compute policy for all possible x and v (with discretization)
    xs = np.linspace(unwrapped_env.min_position, unwrapped_env.max_position, 100)
    vs = np.linspace(-unwrapped_env.max_speed, unwrapped_env.max_speed, 100)

    grid = np.dstack(np.meshgrid(xs, vs[::-1])).transpose(1, 0, 2)
    grid_flat = grid.reshape(len(xs) * len(vs), 2)
    probs = (
        agent.predict_proba(grid_flat).reshape(len(xs), len(vs), 3).transpose(1, 0, 2)
    )

    # Draw policy
    f, ax = plt.subplots(figsize=(7, 7))
    ax.imshow(
        probs,
        extent=(unwrapped_env.min_position, unwrapped_env.max_position, 
                -unwrapped_env.max_speed, unwrapped_env.max_speed),
        aspect="auto",
    )
    ax.set_title("Learned policy: red=left, green=nothing, blue=right")
    ax.set_xlabel("position (x)")
    ax.set_ylabel("velocity (v)")

    # Sample a trajectory and draw it
    states, actions, _ = generate_session(env, agent)
    states = np.array(states)
    ax.plot(states[:, 0], states[:, 1], color="white")

    # Draw every 3rd action from the trajectory
    for (x, v), a in zip(states[::3], actions[::3]):
        if a == 0:
            plt.arrow(x, v, -0.1, 0, color="white", head_length=0.02)
        elif a == 2:
            plt.arrow(x, v, 0.1, 0, color="white", head_length=0.02)

# Also fix the typo in render_mode
with gym.make("MountainCar-v0", render_mode="rgb_array"):    visualize_mountain_car(env, agent)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 44
#      41             plt.arrow(x, v, 0.1, 0, color="white", head_length=0.02)
#      43 # Also fix the typo in render_mode
# ---> 44 with gym.make("MountainCar-v0", render_mode="rgb_array"):    visualize_mountain_car(env, agent)
#
# Cell In[11], line 16, in visualize_mountain_car(env, agent)
#      13 grid = np.dstack(np.meshgrid(xs, vs[::-1])).transpose(1, 0, 2)
#      14 grid_flat = grid.reshape(len(xs) * len(vs), 2)
#      15 probs = (
# ---> 16     agent.predict_proba(grid_flat).reshape(len(xs), len(vs), 3).transpose(1, 0, 2)
#      17 )
#      19 # Draw policy
#      20 f, ax = plt.subplots(figsize=(7, 7))
#
# File ~\miniconda3\envs\rl_env\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1370, in MLPClassifier.predict_proba(self, X)
#    1356 """Probability estimates.
#    1357
# ...

# %% [markdown]
# # Моё решение дз (часть II)

# %% [markdown]
# 2.1 **For LunarLander, get average reward of at least +50** (выбрал LunarLander).

# %% [markdown]
# Посмотрим на среду

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# if you see "<classname> has no attribute .env", remove .env or update gym
env = gym.make("LunarLander-v3", render_mode="rgb_array").env

env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape[0]

plt.imshow(env.render())
print("state vector dim =", state_dim)
print("n_actions =", n_actions)

env.close()
# Out:
# state vector dim = 8
# n_actions = 4

# %% [markdown]
# В качестве политики выберем нейронку, количество нейронов будем позже менять

# %%
from sklearn.neural_network import MLPClassifier

NUM_NEURONS = 30

agent = MLPClassifier(
    hidden_layer_sizes=(NUM_NEURONS, NUM_NEURONS),
    activation="tanh",
)

# initialize agent to the dimension of state space and number of actions
agent.partial_fit([env.reset()[0]] * n_actions, list(range(n_actions)), classes=list(range(n_actions)))
# Out:
# MLPClassifier(activation='tanh', hidden_layer_sizes=(30, 30))

# %% [markdown]
# Обучим агента

# %%
n_sessions = 100
percentile = 50
log = []

for i in range(1000):
    # generate new sessions
    # sessions = [ <YOUR CODE: generate a list of n_sessions new sessions> ]
    sessions = [ generate_session(env, agent) for _ in range(n_sessions)]
    # states_batch, actions_batch, rewards_batch = map(np.array, zip(*sessions))
    states_batch, actions_batch, rewards_batch = zip(*sessions)
    # elite_states, elite_actions = <YOUR CODE: select elite actions just like before>
    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)
    #<YOUR CODE: partial_fit agent to predict elite_actions(y) from elite_states(X)>

    agent.partial_fit(elite_states, elite_actions)

    show_progress(
        rewards_batch, log, percentile, reward_range=[-200, 250]
    )

    if np.mean(rewards_batch) > 50:
        print("We Win!")
        break
# Out:
# mean reward = 50.815, threshold=34.650
# We Win!

# %% [markdown]
# 2.2 **Devise a way to speed up training against the default version**

# %% [markdown]
# Во-первых, замерим текущую скорость обучения, чтобы был baseline

# %%
import gymnasium as gym
import numpy as np
import time
env = gym.make("LunarLander-v3", render_mode="rgb_array").env
n_actions = env.action_space.n
from sklearn.neural_network import MLPClassifier
NUM_NEURONS = 30
agent = MLPClassifier(
    hidden_layer_sizes=(NUM_NEURONS, NUM_NEURONS),
    activation="tanh",
)
agent.partial_fit([env.reset()[0]] * n_actions, list(range(n_actions)), classes=list(range(n_actions)))
n_sessions = 100
percentile = 50
# Мы считаем время за несколько итераций обучения и усредняем по количеству итераций [время - в секундах]
execution_times = []
for i in range(10):
    start = time.perf_counter()
    sessions = [ generate_session(env, agent) for _ in range(n_sessions)]
    states_batch, actions_batch, rewards_batch = zip(*sessions)
    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)
    agent.partial_fit(elite_states, elite_actions)
    end = time.perf_counter()
    execution_times.append(end-start)
    print(f"Iteration {i} - {end-start} seconds")
# Out:
# Iteration 0 - 3.905789700000014 seconds
# Iteration 1 - 3.5195845999999165 seconds
# Iteration 2 - 3.7334723999999824 seconds
# Iteration 3 - 3.843968200000063 seconds
# Iteration 4 - 3.6225306999999702 seconds
# Iteration 5 - 3.88544909999996 seconds
# Iteration 6 - 3.805616799999825 seconds
# Iteration 7 - 3.81545600000004 seconds
# Iteration 8 - 3.9140628000000106 seconds
# Iteration 9 - 4.055174800000032 seconds

# %%
average_time_base_version = np.mean(np.asarray(execution_times))
average_time_base_version
# Out:
# np.float64(3.8101105099999812)

# %% [markdown]
# *Obvious improvement: use joblib. However, note that you will probably need to spawn a new environment in each of the workers instead of passing it via pickling.*

# %%
import gymnasium as gym
import numpy as np
from joblib import Parallel, delayed
import time
env = gym.make("LunarLander-v3")
n_actions = env.action_space.n
from sklearn.neural_network import MLPClassifier
NUM_NEURONS = 30
agent = MLPClassifier(
    hidden_layer_sizes=(NUM_NEURONS, NUM_NEURONS),
    activation="tanh",
)
agent.partial_fit([env.reset()[0]] * n_actions, list(range(n_actions)), classes=list(range(n_actions)))
n_sessions = 100
percentile = 50
# Мы считаем время за несколько итераций обучения и усредняем по количеству итераций [время - в секундах]
execution_times_joblib = []
def generate_session_joblib(env_name, ag):
    return generate_session(gym.make(env_name), ag)
for i in range(10):
    start = time.perf_counter()
    sessions = Parallel(n_jobs=-1)(
        delayed(generate_session_joblib)("LunarLander-v3", agent) for _ in range(n_sessions)
    )
    states_batch, actions_batch, rewards_batch = zip(*sessions)
    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)
    agent.partial_fit(elite_states, elite_actions)
    end = time.perf_counter()
    execution_times_joblib.append(end-start)
    print(f"Iteration {i} - {end-start} seconds")
# Out:
# Iteration 0 - 4.1707258000001275 seconds
# Iteration 1 - 0.9959539999999834 seconds
# Iteration 2 - 0.9954350000000431 seconds
# Iteration 3 - 1.0078384000000824 seconds
# Iteration 4 - 1.055474699999877 seconds
# Iteration 5 - 0.9815525000001344 seconds
# Iteration 6 - 1.0018954999998186 seconds
# Iteration 7 - 1.3577717999999095 seconds
# Iteration 8 - 0.9483187999999245 seconds
# Iteration 9 - 0.9922589999998763 seconds

# %%
average_time_joblib_version = np.mean(np.asarray(execution_times_joblib))
average_time_joblib_version
# Out:
# np.float64(1.3507225499999778)

# %% [markdown]
# Ускорение примерно в 4 раза, что ожидаемо (на моём старом пк 4 ядра)

# %% [markdown]
# *Try re-using samples from 3-5 last iterations when computing threshold and training.* -- как я понял, это про большее увеличение средней награды за шаг и стабилизацию процесса обучения в целом. Поэтому надо сравнить прогресс БЕЗ и С этим изменением.

# %% [markdown]
# Запишем прогресс БЕЗ использования нескольких последних итераций.

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
env = gym.make("LunarLander-v3")
n_actions = env.action_space.n
from sklearn.neural_network import MLPClassifier
NUM_NEURONS = 30
agent = MLPClassifier(
    hidden_layer_sizes=(NUM_NEURONS, NUM_NEURONS),
    activation="tanh",
)
agent.partial_fit([env.reset()[0]] * n_actions, list(range(n_actions)), classes=list(range(n_actions)))
n_sessions = 100
percentile = 50
def generate_session_joblib(env_name, ag):
    return generate_session(gym.make(env_name), ag)
log_base_joblib = []
for i in range(300):
    sessions = Parallel(n_jobs=-1)(
        delayed(generate_session_joblib)("LunarLander-v3", agent) for _ in range(n_sessions)
    )
    states_batch, actions_batch, rewards_batch = zip(*sessions)
    elite_states, elite_actions = select_elites(states_batch, actions_batch, rewards_batch, percentile)
    agent.partial_fit(elite_states, elite_actions)
    show_progress(
        rewards_batch, log_base_joblib, percentile, reward_range=[-200, 250]
    )
# Out:
# mean reward = 135.651, threshold=148.136

# %% [markdown]
# Теперь запишем прогресс С использованием нескольких последних итераций

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
logs_modified_jobib = []
for max_buffer_size in [3,4,5]:
    env = gym.make("LunarLander-v3")
    n_actions = env.action_space.n
    from sklearn.neural_network import MLPClassifier
    NUM_NEURONS = 30
    agent = MLPClassifier(
        hidden_layer_sizes=(NUM_NEURONS, NUM_NEURONS),
        activation="tanh",
    )
    agent.partial_fit([env.reset()[0]] * n_actions, list(range(n_actions)), classes=list(range(n_actions)))
    n_sessions = 100
    percentile = 50
    def generate_session_joblib(env_name, ag):
        return generate_session(gym.make(env_name), ag)
    log_modified_joblib = []
    buffer_iterations = []
    for i in range(300):
        sessions = Parallel(n_jobs=-1)(
            delayed(generate_session_joblib)("LunarLander-v3", agent) for _ in range(n_sessions)
        )
        states_batch, actions_batch, rewards_batch = zip(*sessions)
    
        buffer_iterations.append((states_batch, actions_batch, rewards_batch))
    
        # Удаляем самую старую итерацию, если превышен лимит
        if len(buffer_iterations) > max_buffer_size:
            buffer_iterations.pop(0)
    
        all_states = []
        all_actions = []
        all_rewards = []
        for sb, ab, rb in buffer_iterations:
            all_states.extend(sb)
            all_actions.extend(ab)
            all_rewards.extend(rb)
        
        elite_states, elite_actions = select_elites(all_states, all_actions, all_rewards, percentile)
        agent.partial_fit(elite_states, elite_actions)
        show_progress(
            rewards_batch, log_modified_joblib, percentile, reward_range=[-200, 250]
        )
    logs_modified_jobib.append(log_modified_joblib)
# Out:
# mean reward = 141.150, threshold=150.921

# %%
plt.figure(figsize=[8, 4])
plt.subplot(1, 1, 1)
plt.plot(list(zip(*log_base_joblib))[0], label="Mean rewards base")

plt.plot(list(zip(*(logs_modified_jobib[0])))[0], label="Mean rewards 3 iter")
plt.plot(list(zip(*(logs_modified_jobib[1])))[0], label="Mean rewards 4 iter")
plt.plot(list(zip(*(logs_modified_jobib[2])))[0], label="Mean rewards 5 iter")
# plt.plot(list(zip(*log))[1], label="Reward thresholds")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Лучший эффект дало только использование 5 последних итераций, причём видно, что процесс обучения стал более устойчивым, но долгим. 3 и 4 итерации показали себя не очень хорошо, на 300 прогонов дав худший результат чем baseline.

# %% [markdown]
# *Obtain -100 at MountainCar-v0 or +200 at LunarLander-v2 (2 pts). Feel free to experiment with hyperparameters, architectures, schedules etc.*

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
env = gym.make("LunarLander-v3")
n_actions = env.action_space.n
from sklearn.neural_network import MLPClassifier
agent = MLPClassifier(
    hidden_layer_sizes=(30),
)
agent.partial_fit([env.reset()[0]] * n_actions, list(range(n_actions)), classes=list(range(n_actions)))
n_sessions = 100
percentile = 50
max_buffer_size = 5
def generate_session_joblib(env_name, ag):
    return generate_session(gym.make(env_name), ag)
log = []
buffer_iterations = []
for i in range(1000):
    sessions = Parallel(n_jobs=-1)(
    delayed(generate_session_joblib)("LunarLander-v3", agent) for _ in range(n_sessions)
    )
    states_batch, actions_batch, rewards_batch = zip(*sessions)

    buffer_iterations.append((states_batch, actions_batch, rewards_batch))

    # Удаляем самую старую итерацию, если превышен лимит
    if len(buffer_iterations) > max_buffer_size:
        buffer_iterations.pop(0)

    all_states = []
    all_actions = []
    all_rewards = []
    for sb, ab, rb in buffer_iterations:
        all_states.extend(sb)
        all_actions.extend(ab)
        all_rewards.extend(rb)
    
    # 1. Отбираем элиты (пока в сыром виде)
    elite_states, elite_actions = select_elites(all_states, all_actions, all_rewards, percentile)
    
    # 4. Обучаем агента на нормализованных данных
    agent.partial_fit(elite_states, elite_actions)
    show_progress(
        rewards_batch, log, percentile, reward_range=[-200, 250]
    )
    if np.mean(rewards_batch) > 200:
        print("We Win!")
        break
# Out:
# mean reward = 200.962, threshold=191.971
# We Win!

# %% [markdown]
# ### Bonus tasks
#
# * __2.3 bonus__ (2 pts) Try to find a network architecture and training params that solve __both__ environments above (_Points depend on implementation. If you attempted this task, please mention it in Anytask submission._)
#
# * __2.4 bonus__ (4 pts) Solve continuous action space task with `MLPRegressor` or similar.
#   * Since your agent only predicts the "expected" action, you will have to add noise to ensure exploration.
#   * Choose one of [MountainCarContinuous-v0](https://gymnasium.farama.org/environments/classic_control/mountain_car_continuous/) (90+ pts to solve), [LunarLanderContinuous-v2](https://gymnasium.farama.org/environments/box2d/lunar_lander/) (`env = gym.make("LunarLander-v2", continuous=True)`)(200+ pts to solve)
#   * 4 points for solving. Slightly less for getting some results below solution threshold. Note that discrete and continuous environments may have slightly different rules, aside from action spaces.
