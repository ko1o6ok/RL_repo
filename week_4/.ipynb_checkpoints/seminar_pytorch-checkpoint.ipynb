# %% [markdown]
# # Approximate q-learning
#
# In this notebook you will teach a __PyTorch__ neural network to do Q-learning.

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# /bin/bash: ../xvfb: No such file or directory

# %%
# !pip install gymnasium[classic_control]
# Out:
# Requirement already satisfied: gymnasium[classic_control] in C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages (from gymnasium[classic_control]) (2.4.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages (from gymnasium[classic_control]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages (from gymnasium[classic_control]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages (from gymnasium[classic_control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages (from gymnasium[classic_control]) (2.6.1)

# %%
import gymnasium as gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array").env
env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape

plt.imshow(env.render())
env.close()

# %% [markdown]
# # Approximate Q-learning: building the network
#
# To train a neural network policy one must have a neural network policy. Let's build it.
#
#
# Since we're working with a pre-extracted features (cart positions, angles and velocities), we don't need a complicated network yet. In fact, let's build something like this for starters:
#
# ![img](https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/yet_another_week/_resource/qlearning_scheme.png)
#
# For your first run, please only use linear layers (`nn.Linear`) and activations. Stuff like batch normalization or dropout may ruin everything if used haphazardly.
#
# Also please avoid using nonlinearities like sigmoid & tanh: since agent's observations are not normalized, sigmoids might be saturated at initialization. Instead, use non-saturating nonlinearities like ReLU.
#
# Ideally you should start small with maybe 1-2 hidden layers with < 200 neurons and then increase network size if agent doesn't beat the target score.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
network = nn.Sequential()

network.add_module('layer1', nn.Linear(state_dim[0], 50))
network.add_module('layer2', nn.ReLU())
network.add_module('layer3', nn.Linear(50, n_actions))
#<YOUR CODE: stack layers!!!1>

# hint: use state_dim[0] as input size

# %%
def get_action(state, epsilon=0):
    """
    sample actions with epsilon-greedy policy
    recap: with p = epsilon pick random action, else pick action with highest Q(s,a)
    """
    state = torch.tensor(state[None], dtype=torch.float32)
    q_values = network(state).detach().numpy()

    optimal_action = np.argmax(q_values)

    return int(np.random.choice(n_actions) if np.random.random() < epsilon else optimal_action )

# %%
s, _ = env.reset()
assert tuple(network(torch.tensor([s]*3, dtype=torch.float32)).size()) == (
    3, n_actions), "please make sure your model maps state s -> [Q(s,a0), ..., Q(s, a_last)]"
assert isinstance(list(network.modules(
))[-1], nn.Linear), "please make sure you predict q-values without nonlinearity (ignore if you know what you're doing)"
assert isinstance(get_action(s), int), "get_action(s) must return int, not %s. try int(action)" % (type(get_action(s)))

# test epsilon-greedy exploration
for eps in [0., 0.1, 0.5, 1.0]:
    state_frequencies = np.bincount(
        [get_action(s, epsilon=eps) for i in range(10000)], minlength=n_actions)
    best_action = state_frequencies.argmax()
    assert abs(state_frequencies[best_action] -
               10000 * (1 - eps + eps / n_actions)) < 200
    for other_action in range(n_actions):
        if other_action != best_action:
            assert abs(state_frequencies[other_action] -
                       10000 * (eps / n_actions)) < 200
    print('e=%.1f tests passed' % eps)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12020\2259198421.py:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   assert tuple(network(torch.tensor([s]*3, dtype=torch.float32)).size()) == (
# e=0.0 tests passed
# e=0.1 tests passed
# e=0.5 tests passed
# e=1.0 tests passed

# %% [markdown]
# ### Q-learning via gradient descent
#
# We shall now train our agent's Q-function by minimizing the TD loss:
# $$ L = { 1 \over N} \sum_i (Q_{\theta}(s,a) - [r(s,a) + \gamma \cdot max_{a'} Q_{-}(s', a')]) ^2 $$
#
#
# Where
# * $s, a, r, s'$ are current state, action, reward and next state respectively
# * $\gamma$ is a discount factor defined two cells above.
#
# The tricky part is with  $Q_{-}(s',a')$. From an engineering standpoint, it's the same as $Q_{\theta}$ - the output of your neural network policy. However, when doing gradient descent, __we won't propagate gradients through it__ to make training more stable (see lectures).
#
# To do so, we shall use `x.detach()` function which basically says "consider this thing constant when doing backprop".

# %%
def compute_td_loss(states, actions, rewards, next_states, is_done, gamma=0.99, check_shapes=False):
    """ Compute td loss using torch operations only. Use the formula above. """
    states = torch.tensor(
        states, dtype=torch.float32)                                  # shape: [batch_size, state_size]
    actions = torch.tensor(actions, dtype=torch.long)                 # shape: [batch_size]
    rewards = torch.tensor(rewards, dtype=torch.float32)              # shape: [batch_size]
    # shape: [batch_size, state_size]
    next_states = torch.tensor(next_states, dtype=torch.float32)
    is_done = torch.tensor(is_done, dtype=torch.uint8)                # shape: [batch_size]

    # get q-values for all actions in current states
    predicted_qvalues = network(states)                               # shape: [batch_size, n_actions]

    # select q-values for chosen actions
    predicted_qvalues_for_actions = predicted_qvalues[                # shape: [batch_size]
      range(states.shape[0]), actions
    ]

    # compute q-values for all actions in next states
    predicted_next_qvalues = network(next_states)

    next_actions = predicted_next_qvalues.argmax(dim=1)

    # compute V*(next_states) using predicted next q-values
    next_state_values = predicted_next_qvalues[range(len(next_states)), next_actions]
    assert next_state_values.dtype == torch.float32

    # compute "target q-values" for loss - it's what's inside square parentheses in the above formula.
    target_qvalues_for_actions = rewards + gamma * next_state_values.detach()

    # at the last state we shall use simplified formula: Q(s,a) = r(s,a) since s' doesn't exist
    target_qvalues_for_actions = torch.where(
        is_done, rewards, target_qvalues_for_actions)

    # mean squared error loss to minimize
    loss = torch.mean((predicted_qvalues_for_actions -
                       target_qvalues_for_actions.detach()) ** 2)

    if check_shapes:
        assert predicted_next_qvalues.data.dim(
        ) == 2, "make sure you predicted q-values for all actions in next state"
        assert next_state_values.data.dim(
        ) == 1, "make sure you computed V(s') as maximum over just the actions axis and not all axes"
        assert target_qvalues_for_actions.data.dim(
        ) == 1, "there's something wrong with target q-values, they must be a vector"

    return loss

# %%
# sanity checks
s, _ = env.reset()
a = env.action_space.sample()
next_s, r, terminated, _, _ = env.step(a)
loss = compute_td_loss([s], [a], [r], [next_s], [terminated], check_shapes=True)
loss.backward()

assert len(loss.size()) == 0, "you must return scalar loss - mean over batch"
assert np.any(next(network.parameters()).grad.detach().numpy() !=
              0), "loss must be differentiable w.r.t. network weights"

# %% [markdown]
# ### Playing the game

# %%
opt = torch.optim.Adam(network.parameters(), lr=1e-4)

# %%
def generate_session(env, t_max=1000, epsilon=0, train=False):
    """play env with approximate q-learning agent and train it at the same time"""
    total_reward = 0
    s, _ = env.reset()

    for t in range(t_max):
        a = get_action(s, epsilon=epsilon)
        next_s, r, terminated, truncated, _ = env.step(a)

        if train:
            opt.zero_grad()
            compute_td_loss([s], [a], [r], [next_s], [terminated]).backward()
            opt.step()

        total_reward += r
        s = next_s
        if terminated or truncated:
            break

    return total_reward

# %%
epsilon = 0.5

# %%
for i in range(1000):
    session_rewards = [generate_session(env, epsilon=epsilon, train=True) for _ in range(100)]
    print("epoch #{}\tmean reward = {:.3f}\tepsilon = {:.3f}".format(i, np.mean(session_rewards), epsilon))

    epsilon *= 0.99
    assert epsilon >= 1e-4, "Make sure epsilon is always nonzero during training"

    if np.mean(session_rewards) > 300:
        print("You Win!")
        break
# Out:
# epoch #0	mean reward = 15.340	epsilon = 0.500
# epoch #1	mean reward = 13.830	epsilon = 0.495
# epoch #2	mean reward = 13.730	epsilon = 0.490
# epoch #3	mean reward = 13.680	epsilon = 0.485
# epoch #4	mean reward = 15.010	epsilon = 0.480
# epoch #5	mean reward = 17.930	epsilon = 0.475
# epoch #6	mean reward = 13.440	epsilon = 0.471
# epoch #7	mean reward = 13.520	epsilon = 0.466
# epoch #8	mean reward = 13.420	epsilon = 0.461
# epoch #9	mean reward = 13.790	epsilon = 0.457
# epoch #10	mean reward = 17.660	epsilon = 0.452
# epoch #11	mean reward = 13.210	epsilon = 0.448
# epoch #12	mean reward = 13.090	epsilon = 0.443
# epoch #13	mean reward = 14.250	epsilon = 0.439
# epoch #14	mean reward = 14.660	epsilon = 0.434
# epoch #15	mean reward = 13.170	epsilon = 0.430
# epoch #16	mean reward = 14.870	epsilon = 0.426
# epoch #17	mean reward = 16.980	epsilon = 0.421
# epoch #18	mean reward = 13.780	epsilon = 0.417
# epoch #19	mean reward = 15.730	epsilon = 0.413
# epoch #20	mean reward = 17.860	epsilon = 0.409
# epoch #21	mean reward = 11.710	epsilon = 0.405
# epoch #22	mean reward = 16.870	epsilon = 0.401
# epoch #23	mean reward = 17.660	epsilon = 0.397
# epoch #24	mean reward = 14.050	epsilon = 0.393
# epoch #25	mean reward = 13.660	epsilon = 0.389
# epoch #26	mean reward = 19.790	epsilon = 0.385
# epoch #27	mean reward = 12.700	epsilon = 0.381
# epoch #28	mean reward = 12.460	epsilon = 0.377
# epoch #29	mean reward = 15.030	epsilon = 0.374
# epoch #30	mean reward = 12.750	epsilon = 0.370
# epoch #31	mean reward = 11.750	epsilon = 0.366
# epoch #32	mean reward = 12.360	epsilon = 0.362
# epoch #33	mean reward = 17.420	epsilon = 0.359
# epoch #34	mean reward = 12.630	epsilon = 0.355
# epoch #35	mean reward = 26.360	epsilon = 0.352
# epoch #36	mean reward = 28.660	epsilon = 0.348
# epoch #37	mean reward = 23.190	epsilon = 0.345
# epoch #38	mean reward = 22.470	epsilon = 0.341
# epoch #39	mean reward = 23.480	epsilon = 0.338
# epoch #40	mean reward = 22.230	epsilon = 0.334
# epoch #41	mean reward = 15.540	epsilon = 0.331
# epoch #42	mean reward = 26.500	epsilon = 0.328
# epoch #43	mean reward = 34.490	epsilon = 0.325
# epoch #44	mean reward = 30.760	epsilon = 0.321
# epoch #45	mean reward = 32.280	epsilon = 0.318
# epoch #46	mean reward = 34.290	epsilon = 0.315
# epoch #47	mean reward = 33.380	epsilon = 0.312
# epoch #48	mean reward = 18.370	epsilon = 0.309
# epoch #49	mean reward = 18.530	epsilon = 0.306
# epoch #50	mean reward = 39.780	epsilon = 0.303
# epoch #51	mean reward = 37.750	epsilon = 0.299
# epoch #52	mean reward = 24.560	epsilon = 0.296
# epoch #53	mean reward = 35.800	epsilon = 0.294
# epoch #54	mean reward = 32.340	epsilon = 0.291
# epoch #55	mean reward = 30.110	epsilon = 0.288
# epoch #56	mean reward = 45.150	epsilon = 0.285
# epoch #57	mean reward = 22.640	epsilon = 0.282
# epoch #58	mean reward = 31.490	epsilon = 0.279
# epoch #59	mean reward = 40.200	epsilon = 0.276
# epoch #60	mean reward = 21.900	epsilon = 0.274
# epoch #61	mean reward = 53.510	epsilon = 0.271
# epoch #62	mean reward = 36.400	epsilon = 0.268
# epoch #63	mean reward = 35.840	epsilon = 0.265
# epoch #64	mean reward = 57.210	epsilon = 0.263
# epoch #65	mean reward = 44.120	epsilon = 0.260
# epoch #66	mean reward = 50.410	epsilon = 0.258
# epoch #67	mean reward = 68.640	epsilon = 0.255
# epoch #68	mean reward = 65.370	epsilon = 0.252
# epoch #69	mean reward = 13.790	epsilon = 0.250
# epoch #70	mean reward = 37.310	epsilon = 0.247
# epoch #71	mean reward = 20.390	epsilon = 0.245
# epoch #72	mean reward = 32.460	epsilon = 0.242
# epoch #73	mean reward = 13.410	epsilon = 0.240
# epoch #74	mean reward = 76.790	epsilon = 0.238
# epoch #75	mean reward = 10.680	epsilon = 0.235
# epoch #76	mean reward = 14.280	epsilon = 0.233
# epoch #77	mean reward = 10.560	epsilon = 0.231
# epoch #78	mean reward = 11.230	epsilon = 0.228
# epoch #79	mean reward = 16.840	epsilon = 0.226
# epoch #80	mean reward = 15.710	epsilon = 0.224
# epoch #81	mean reward = 11.480	epsilon = 0.222
# epoch #82	mean reward = 20.530	epsilon = 0.219
# epoch #83	mean reward = 17.860	epsilon = 0.217
# epoch #84	mean reward = 15.620	epsilon = 0.215
# epoch #85	mean reward = 25.690	epsilon = 0.213
# epoch #86	mean reward = 25.520	epsilon = 0.211
# epoch #87	mean reward = 13.430	epsilon = 0.209
# epoch #88	mean reward = 31.490	epsilon = 0.206
# epoch #89	mean reward = 27.660	epsilon = 0.204
# epoch #90	mean reward = 30.870	epsilon = 0.202
# epoch #91	mean reward = 54.650	epsilon = 0.200
# epoch #92	mean reward = 31.320	epsilon = 0.198
# epoch #93	mean reward = 30.070	epsilon = 0.196
# epoch #94	mean reward = 53.090	epsilon = 0.194
# epoch #95	mean reward = 63.480	epsilon = 0.192
# epoch #96	mean reward = 70.490	epsilon = 0.191
# epoch #97	mean reward = 86.430	epsilon = 0.189
# epoch #98	mean reward = 70.840	epsilon = 0.187
# epoch #99	mean reward = 11.310	epsilon = 0.185
# epoch #100	mean reward = 23.900	epsilon = 0.183
# epoch #101	mean reward = 34.170	epsilon = 0.181
# epoch #102	mean reward = 56.900	epsilon = 0.179
# epoch #103	mean reward = 47.710	epsilon = 0.178
# epoch #104	mean reward = 26.430	epsilon = 0.176
# epoch #105	mean reward = 43.830	epsilon = 0.174
# epoch #106	mean reward = 29.870	epsilon = 0.172
# epoch #107	mean reward = 53.700	epsilon = 0.171
# epoch #108	mean reward = 49.610	epsilon = 0.169
# epoch #109	mean reward = 67.830	epsilon = 0.167
# epoch #110	mean reward = 72.990	epsilon = 0.166
# epoch #111	mean reward = 80.560	epsilon = 0.164
# epoch #112	mean reward = 90.550	epsilon = 0.162
# epoch #113	mean reward = 90.600	epsilon = 0.161
# epoch #114	mean reward = 108.800	epsilon = 0.159
# epoch #115	mean reward = 132.460	epsilon = 0.157
# epoch #116	mean reward = 153.440	epsilon = 0.156
# epoch #117	mean reward = 180.980	epsilon = 0.154
# epoch #118	mean reward = 210.850	epsilon = 0.153
# epoch #119	mean reward = 238.870	epsilon = 0.151
# epoch #120	mean reward = 248.030	epsilon = 0.150
# epoch #121	mean reward = 297.430	epsilon = 0.148
# epoch #122	mean reward = 348.120	epsilon = 0.147
# You Win!

# %% [markdown]
# ### How to interpret results
#
#
# Welcome to the f.. world of deep f...n reinforcement learning. Don't expect agent's reward to smoothly go up. Hope for it to go increase eventually. If it deems you worthy.
#
# Seriously though,
# * __ mean reward__ is the average reward per game. For a correct implementation it may stay low for some 10 epochs, then start growing while oscilating insanely and converges by ~50-100 steps depending on the network architecture.
# * If it never reaches target score by the end of for loop, try increasing the number of hidden neurons or look at the epsilon.
# * __ epsilon__ - agent's willingness to explore. If you see that agent's already at < 0.01 epsilon before it's is at least 200, just reset it back to 0.1 - 0.5.

# %% [markdown]
# ### Record videos
#
# As usual, we now use `gymnasium.wrappers.RecordVideo` to record a video of our agent playing the game. Unlike our previous attempts with state binarization, this time we expect our agent to act ~~(or fail)~~ more smoothly since there's no more binarization error at play.
#
# As you already did with tabular q-learning, we set epsilon=0 for final evaluation to prevent agent from exploring himself to death.

# %%
# Record sessions

from gymnasium.wrappers import RecordVideo

with gym.make("CartPole-v1", render_mode="rgb_array") as record_env, RecordVideo(
    record_env, video_folder="videos"
) as env_monitor:
    sessions = [
        generate_session(env_monitor, epsilon=0, train=False) for _ in range(100)
    ]
# Out:
# C:\Users\user\miniconda3\envs\rl_env\Lib\site-packages\gymnasium\wrappers\rendering.py:293: UserWarning: WARN: Overwriting existing videos at D:\Мага_1_год_весна\RL\notebooks\week_4\videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
# Show video. This may not work in some setups. If it doesn't
# work for you, you can download the videos and view them locally.

from pathlib import Path
from base64 import b64encode
from IPython.display import HTML

video_paths = sorted([s for s in Path('videos').iterdir() if s.suffix == '.mp4'])
video_path = video_paths[-1]  # You can also try other indices

if 'google.colab' in sys.modules:
    # https://stackoverflow.com/a/57378660/1214547
    with video_path.open('rb') as fp:
        mp4 = fp.read()
    data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
else:
    data_url = str(video_path)

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(data_url))
# Out:
# <video width="640" height="480" controls>
#   <source src="videos\rl-video-episode-8.mp4" type="video/mp4">
# </video>
